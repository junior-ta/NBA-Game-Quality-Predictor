# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# %%
#Creatimg my dataframe with column names scraped beforehand
df= pd.DataFrame(columns=['Rank',
 'Season',
 'Date',
 'Score',
 'Excitment',
 'Tension',
 'Comeback',
 'MVP',
 'LVP'])

start_date = datetime(2024, 10, 22)
end_date = datetime(2025, 4, 13)

current_date = start_date
while current_date <= end_date:
    #print(current_date.strftime("%Y-%m-%d"))  # or just use current_date
    url= f"https://stats.inpredictable.com/nba/topGame.php?sort=ei&season=2024&team=ALL&po=0&frdt={current_date.strftime('%Y-%m-%d')}&todt={current_date.strftime('%Y-%m-%d')}"
    page= requests.get(url)
    soup= BeautifulSoup(page.text, 'html')

    table= soup.find('table')

    ##Getting columns
    columns= soup.find_all('th')
    columns_list= [column.text for column in columns]

    #getting rows
    rows= table.find_all('tr')[1:]

    rows_list=[]
    for row in rows:
        curr= row.find_all('td')
        curr.pop(4)
        rows_list.append([data.text for data in curr])

    for row in rows_list:
        df.loc[len(df)]= row

    current_date += timedelta(days=1)

df.drop(['Rank'], axis=1, inplace=True)
df.to_csv()
df
# Out:
#      Season        Date             Score Excitement Tension Comeback  \
# 0      2024  2024-10-22  MIN 103, LAL 110        5.4    65.9      1.2
# 1      2024  2024-10-22  NYK 109, BOS 132        2.0    37.1      1.0
# 2      2024  2024-10-23  PHX 116, LAC 113       11.0    86.8     32.8
# 3      2024  2024-10-23  MEM 126, UTA 124        9.1    82.7      1.4
# 4      2024  2024-10-23  CHA 110, HOU 105        9.0    81.2      9.5
# ...     ...         ...               ...        ...     ...      ...
# 1212   2024  2025-04-13  ORL 105, ATL 117        4.9    64.8      1.3
# 1213   2024  2025-04-13  OKC 115, NOP 100        3.7    49.9      1.0
# 1214   2024  2025-04-13   LAL 81, POR 109        3.5    52.8      1.0
# 1215   2024  2025-04-13   DAL 97, MEM 132        3.2    50.6      1.6
# 1216   2024  2025-04-13  DEN 126, HOU 111        3.2    49.1      1.2
#
#                      MVP                   LVP
# 0       A. Davis: +19.7%     M. Conley: -13.3%
# 1       J. Tatum: +17.4%     M. Bridges: -6.7%
# 2        B. Beal: +36.8%     N. Powell: -19.7%
# 3      S. Aldama: +31.2%     K. George: -27.8%
# 4       J. Green: +31.6%      V. Mici?: -16.3%
# ...                  ...                   ...
# 1212   G. Harris: +12.4%  W. Carter Jr.: -5.7%
# 1213  A. Wiggins: +15.3%   J. Alvarado: -14.3%
# 1214    J. Walker: +9.4%       B. James: -9.4%
# 1215  C. Spencer: +12.7%     G. Jackson: -6.9%
# 1216    N. Joki?: +12.6%       J. Green: -9.3%
#
# [1217 rows x 8 columns]
